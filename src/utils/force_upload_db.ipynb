# %%
import pandas as pd
import os
from dotenv import load_dotenv
from pymongo import MongoClient

load_dotenv()

mongo_connection_string = os.getenv("MONGO_CONNECTION_STRING")

client = MongoClient(mongo_connection_string)
db = client['stock_news_db']
collection = db['news_data']

# %%
df = pd.read_csv("../../data/processed/gemini_nvda_2025-07-26_15-44.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0  The Best Artificial Intelligence  ( AI )  Stoc...
# 1  The Best Artificial Intelligence (AI) Stock to...
# 2              Booz Allen Misses Fiscal Q1 Estimates
# 3    ServiceNow: The 2nd Wave of AI Spending Is Here
# 4  3 Millionaire-Maker Artificial Intelligence  (...
#
#                                                  url publish_date  \
# 0  https://www.fool.com/investing/2025/07/26/the-...   2025-07-26
# 1  https://www.fool.com/investing/2025/07/26/the-...   2025-07-26
# 2  https://www.fool.com/data-news/2025/07/25/booz...   2025-07-25
# 3  https://www.investing.com/analysis/servicenow-...   2025-07-25
# 4  https://www.fool.com/investing/2025/07/25/3-mi...   2025-07-25
#
#   publish_time           source  ticker sentiment  importance  \
# 0        07:15      Motley Fool  NVIDIA  Positive           4
# 1        07:15  The Motley Fool  NVIDIA   Neutral           1
# 2        22:39      Motley Fool  NVIDIA  Negative           1
# 3        22:17    Investing.com  NVIDIA  Positive           4
# 4        21:30      Motley Fool  NVIDIA  Positive           3
#
#                                              summary  \
# 0  The article suggests that NVDA is the best AI ...
# 1  The article recommends Alphabet as the best AI...
# 2  Booz Allen Hamilton (BAH) reported fiscal Q1 2...
# 3  ServiceNow's Q2 results show strong revenue gr...
# 4  The article highlights three AI stocks with th...
#
#                                            translate
# 0  บทความแนะนำว่า NVDA เป็น the best AI stock ที่...
# 1  บทความแนะนำ Alphabet ว่าเป็น the best AI stock...
# 2  Booz Allen Hamilton (BAH) รายงานผลประกอบการ fi...
# 3  ผลประกอบการไตรมาสที่ 2 ของ ServiceNow แสดงให้เ...
# 4  บทความนี้เน้นหุ้น AI สามตัวที่มีศักยภาพในการช่...

# %%
df["ticker"]="NVDA"

# %%
complete_dict = df.to_dict(orient='records')
result = collection.insert_many(complete_dict, ordered=True)
print(f"Inserted {len(result.inserted_ids)} documents to MongoDB")
# Out:
# Inserted 20 documents to MongoDB
