# %% [markdown]
# # Web Scraping from Investing.com
# - Scrape with specific stocks

# %%
import os
import re
import time
import random
import asyncio
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor,  as_completed
import pandas as pd
import nest_asyncio
import cloudscraper
from htmldate import find_date
from bs4 import BeautifulSoup
from newspaper import Article

warnings.filterwarnings('ignore')

# %%
###CONFIGURATION
COMPANY     = "nvidia-corp"   
MAX_PAGE    = 2
MAX_WORKERS = 50              
MAX_RETRIES = 5              

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    ),
    "Accept": (
        "text/html,application/xhtml+xml,application/xml;"
        "q=0.9,image/avif,image/webp,*/*;q=0.8"
    ),
    "Referer": "https://www.investing.com/",
}

scraper = cloudscraper.create_scraper(
    browser={'browser': 'chrome', 'platform': 'windows'}
)

def fetch_page(page: int):
    global ticker
    #Equity
    url = f"https://www.investing.com/equities/{COMPANY}-news/{page}"
    #Index
    #url = f"https://www.investing.com/indices/{COMPANY}-news/{page}"
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            r = scraper.get(url, timeout=30)
            r.raise_for_status()
            soup = BeautifulSoup(r.text, "lxml")
            h1_tag = soup.find('h1', class_='mb-2.5') # Use a specific class or combination of classes for robustness
            full_text = h1_tag.text.strip()
            match = re.search(r'\(([^)]+)\)', full_text)
            ticker = match.group(1)
                    
            anchors = soup.select(
                'ul[data-test="news-list"] '
                'li article a[data-test="article-title-link"]'
            )
            return [a["href"] for a in anchors if a.has_attr("href")]
        except Exception as e:
            if attempt < MAX_RETRIES:
                backoff = 2 ** (attempt - 1) + random.random()
                time.sleep(backoff)
            else:
                print(f"Page {page} failed after {MAX_RETRIES}: {e}")
    return []

def robust_scrape():
    first = fetch_page(1)
    PER_PAGE = len(first)
    if PER_PAGE == 0:
        raise RuntimeError("Failed to fetch the first page. Please check headers or cookies and try again.")
    print(f"Detected {PER_PAGE} links per page, expecting {PER_PAGE * MAX_PAGE} total")

    results = {1: first}
    pages = list(range(2, MAX_PAGE + 1))

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as pool:
        futures = {pool.submit(fetch_page, p): p for p in pages}
        for fut in as_completed(futures):
            p = futures[fut]
            results[p] = fut.result()

        for round in range(1, MAX_RETRIES + 1):
            bad = [p for p, links in results.items() if len(links) != PER_PAGE]
            if not bad:
                print(f"All pages OK after {round-1} retries")
                break
            print(f"Retry round {round} for pages: {bad}")
            futures = {pool.submit(fetch_page, p): p for p in bad}
            for fut in as_completed(futures):
                p = futures[fut]
                results[p] = fut.result()
        else:
            print("Retry limit reached; some pages may still be incomplete.")

    total_fetched = sum(len(links) for links in results.values())
    expected = PER_PAGE * MAX_PAGE
    print(f"Total links fetched (including duplicates): {total_fetched} (expected {expected})")

    all_links = set(link for links in results.values() for link in links)
    print(f"Final: got {len(all_links)} unique URLs (expected {expected})")
    return list(all_links)

if __name__ == "__main__":
    links = robust_scrape()
# Out:
# Detected 10 links per page, expecting 20 total
# All pages OK after 0 retries
# Total links fetched (including duplicates): 20 (expected 20)
# Final: got 20 unique URLs (expected 20)

# %%
links[1]
# Out:
# 'https://www.investing.com/news/stock-market-news/wall-street-analyst-warns-this-is-a-tipping-point-in-the-tesla-story-4126145'

# %%
nest_asyncio.apply()

FETCH_WORKERS = min(32, os.cpu_count() * 4)  
PROCESS_WORKERS = os.cpu_count() or 4
MAX_FETCH_RETRIES = 3                      
RETRY_DELAY = 1                             
TICKER = ticker
scraper = cloudscraper.create_scraper()

def is_placeholder(html: str) -> bool:
    lower = html.lower() if html else ""
    return (
        'temporarily down for maintenance' in lower
        or 'just a moment' in lower
        or "we're temporarily down" in lower
    )

def safe_find_datetime(url, html_content=None):
    try:
        # Strategy 1: Use htmldate library to extract date from URL
        dt = find_date(url)
        if dt:
            return dt, "00:00"  # Return with default time if date found
    except:
        pass
    
    if html_content:
        # Strategy 2: Look for American format with AM/PM
        m = re.search(r"(\d{1,2}/\d{1,2}/\d{4}),\s*(\d{1,2}:\d{2}\s*(?:AM|PM))", html_content)
        if m:
            ds, ts = m.groups()
            try:
                dt = datetime.strptime(f"{ds}, {ts}", "%m/%d/%Y, %I:%M %p")
                return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
            except:
                pass
        
        # Strategy 3: Look for numeric dates with 24-hour time format
        m = re.search(r"(\d{2}/\d{2}/\d{4}),\s*(\d{2}:\d{2})", html_content)
        if m:
            ds, ts = m.groups()
            # Try both European and American date formats
            for fmt in ("%d/%m/%Y, %H:%M", "%m/%d/%Y, %H:%M"):
                try:
                    dt = datetime.strptime(f"{ds}, {ts}", fmt)
                    return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
                except:
                    continue
    
    now = datetime.now()
    return now.strftime("%Y-%m-%d"), now.strftime("%H:%M")

def fetch_html(url, idx, total):
    for attempt in range(1, MAX_FETCH_RETRIES + 1):
        try:
            resp = scraper.get(url, timeout=30)
            html = resp.text
            if is_placeholder(html):
                raise RuntimeError('Placeholder')
                
            print(f"[Fetch][{idx}/{total}][ok]")
            return url, html
            
        except Exception:
            print(f"[Fetch][{idx}/{total}][retry {attempt}]")
            if attempt < MAX_FETCH_RETRIES:
                time.sleep(RETRY_DELAY)
                
    print(f"[Fetch error] {idx}/{total}: failed after {MAX_FETCH_RETRIES} retries")
    return url, None

def process_article(arg):
    url, html = arg
    if not html:
        return None
        
    art = Article(url)
    art.set_html(html)
    
    try:
        art.parse()
    except:
        return None
        
    text = art.text or ""
    title = (art.title or "").strip() or "No title"
    
    date, tm = safe_find_datetime(url, html)
    
    # Return combined data using dictionary unpacking
    return {'ticker': TICKER, 'publish_date': date, 'publish_time': tm,
             'title': title, 'body_text': text, 'url': url}

async def scrape_all(urls):
    total = len(urls)
    loop = asyncio.get_event_loop()
    
    # Phase 1: Fetch HTML content from all URLs in parallel
    with ThreadPoolExecutor(max_workers=FETCH_WORKERS) as fetch_pool:
        # Create fetch tasks and run them through the thread pool
        fetch_tasks = [loop.run_in_executor(fetch_pool, fetch_html, u, i+1, total)
                       for i, u in enumerate(urls)]
        # Wait for all fetch tasks to complete
        fetched = await asyncio.gather(*fetch_tasks)

    # Phase 2: Process all fetched HTML content in parallel
    records = []
    with ThreadPoolExecutor(max_workers=PROCESS_WORKERS) as proc_pool:
        # Submit processing tasks only for URLs with successful fetches
        futures = {
            proc_pool.submit(process_article, fr): fr[0]
            for fr in fetched if fr[1]  # Skip URLs where HTML is None
        }
        
        # Process results as they complete
        for i, fut in enumerate(as_completed(futures), 1):
            res = fut.result()
            print(f"[Process][{i}/{total}] {futures[fut]}")
            if res:
                records.append(res)
                
    # Convert results to DataFrame
    return pd.DataFrame(records)

# ——— Main entry point function ———
def main(links):
    df = asyncio.get_event_loop().run_until_complete(scrape_all(links))
    return df

# Execute the main function if this script is run directly
if __name__ == '__main__':
    df = main(links)
# Out:
# [Fetch][5/20][ok]
# [Fetch][8/20][ok]
# [Fetch][19/20][ok]
# [Fetch][9/20][ok]
# [Fetch][2/20][ok]
# [Fetch][18/20][ok]
# [Fetch][1/20][ok]
# [Fetch][13/20][ok]
# [Fetch][12/20][ok]
# [Fetch][14/20][ok]
# [Fetch][11/20][ok]
# [Fetch][10/20][ok]
# [Fetch][7/20][ok]
# [Fetch][3/20][ok]
# [Fetch][16/20][ok]
# [Fetch][20/20][ok]
# [Fetch][17/20][ok]
# [Fetch][15/20][ok]
# [Fetch][4/20][ok]
# [Fetch][6/20][ok]
# [Process][1/20] https://www.investing.com/news/pro/melius-upgrades-vertiv-holdings-co-to-buy-4125999
# [Process][2/20] https://www.investing.com/news/stock-market-news/schwab-reveals-tesla-tops-retail-investor-buys-in-june-93CH-4127253
# [Process][3/20] https://www.investing.com/news/stock-market-news/who-could-win-and-lose-on-tighter-trump-ai-controls-ubs-weighs-in-4124842
# [Process][4/20] https://www.investing.com/news/economy-news/wall-st-futures-slip-as-markets-await-clarity-on-tariffs-4124259
# [Process][5/20] https://www.investing.com/news/stock-market-news/sk-hynix-shares-rise-as-rival-samsung-sees-sharp-profit-drop-in-q2-4125600
# [Process][6/20] https://www.investing.com/news/economy-news/european-stocks-2025-outperformance-is-over-but-dont-forget-the-euro-4124104
# [Process][7/20] https://www.investing.com/news/stock-market-news/wall-street-analyst-warns-this-is-a-tipping-point-in-the-tesla-story-4126145
# [Process][8/20] https://www.investing.com/news/stock-market-news/nvidia-stock-target-boosted-at-citi-on-expanded-ai-tam-4124395
# [Process][9/20] https://www.investing.com/news/stock-market-news/nvidia-test-slot-could-send-this-stock-soaring-ubs-says-4124723
# [Process][10/20] https://www.investing.com/news/insider-trading-news/nvidia-nvda-ceo-huang-sells-355-million-in-stock-93CH-4125580
# [Process][11/20] https://www.investing.com/news/analyst-ratings/lynx-equity-dismisses-report-on-ai-chip-export-restrictions-to-se-asia-93CH-4124781
# [Process][12/20] https://www.investing.com/news/stock-market-news/temaseks-portfolio-value-hits-record-high-says-us-risks-likely-peaked-4127551
# [Process][13/20] https://www.investing.com/news/stock-market-news/super-micro-to-ramp-up-europe-manufacturing-amid-ai-demand-ceo-liang-tells-cnbc-4127426
# [Process][14/20] https://www.investing.com/news/stock-market-news/samsung-expects-a-56-drop-in-q2-operating-profit-far-short-of-estimates-4125562
# [Process][15/20] https://www.investing.com/news/stock-market-news/ibm-rolls-out-new-chips-and-servers-aims-for-simplified-ai-4126121
# [Process][16/20] https://www.investing.com/news/stock-market-news/singapore-case-against-three-on-ai-chip-fraud-charges-adjourned-until-aug-22-4124629
# [Process][17/20] https://www.investing.com/news/stock-market-news/chinas-ambitious-ai-push-faces-supply-roadblock-in-nvidia-chip-haul--bloomberg-4127359
# [Process][18/20] https://www.investing.com/news/pro/trump-will-be-announcing-semiconductor-tariffs-432SI-4127100
# [Process][19/20] https://www.investing.com/news/stock-market-news/samsung-elec-to-buy-healthcare-services-company-xealth-4125608
# [Process][20/20] https://www.investing.com/news/stock-market-news/with-15-winners-in-july-these-aipicked-stocks-are-now-up-114-4125735

# %%
df=df.sort_values(by=['publish_date', 'publish_time'], ascending=[False,False]).reset_index(drop=True)
df.head()
# Out:
#   ticker publish_date publish_time  \
# 0   NVDA   2025-07-09        03:03
# 1   NVDA   2025-07-08        23:34
# 2   NVDA   2025-07-08        17:43
# 3   NVDA   2025-07-08        16:20
# 4   NVDA   2025-07-08        12:59
#
#                                                title  \
# 0  Temasek’s portfolio value hits record high; sa...
# 1  Super Micro to ramp up Europe manufacturing am...
# 2  China’s ambitious AI push faces supply roadblo...
# 3  Schwab reveals Tesla tops retail investor buys...
# 4  Trump: will be announcing semiconductor tariff...
#
#                                            body_text  \
# 0  By Yantoultra Ngui\n\nSINGAPORE (Reuters) -Sin...
# 1  Investing.com-- Super Micro Computer Inc (NASD...
# 2  Investing.com -- Chinese tech firms have laid ...
# 3  Investing.com -- Leading online broker Schwab ...
# 4  Risk Disclosure: Trading in financial instrume...
#
#                                                  url
# 0  https://www.investing.com/news/stock-market-ne...
# 1  https://www.investing.com/news/stock-market-ne...
# 2  https://www.investing.com/news/stock-market-ne...
# 3  https://www.investing.com/news/stock-market-ne...
# 4  https://www.investing.com/news/pro/trump-will-...

# %%
pd.set_option('display.max_columns', None)

# %%
# Count empty body_text entries
empty_body_count = df[df['body_text'] == ''].shape[0]
print(f"Number of articles with empty body_text: {empty_body_count}")
# Out:
# Number of articles with empty body_text: 0

# %%
now = datetime.now()
date_time = now.strftime("%Y-%m-%d %H-%M-%S").strip().replace(' ', '_')
df.to_csv(f"data/stock_news/{TICKER}_{date_time}.csv".lower(), index=False)
