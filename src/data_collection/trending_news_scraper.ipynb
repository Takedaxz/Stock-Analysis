# %% [markdown]
# # Web Scraping from Investing.com
# - Scrape from trending news

# %%
import os
import re
import time
import random
import asyncio
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor,  as_completed
import pandas as pd
import nest_asyncio
import cloudscraper
from htmldate import find_date
from bs4 import BeautifulSoup
from newspaper import Article

warnings.filterwarnings('ignore')

# %%
import cloudscraper
from bs4 import BeautifulSoup
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

# CONFIGURATION
MAX_WORKERS = 10
MAX_RETRIES = 5

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    ),
    "Accept": (
        "text/html,application/xhtml+xml,application/xml;"
        "q=0.9,image/avif,image/webp,*/*;q=0.8"
    ),
    "Referer": "https://www.investing.com/",
}

scraper = cloudscraper.create_scraper(
    browser={'browser': 'chrome', 'platform': 'windows'}
)

def fetch_page(page: int):
    # If page == 1, use default URL, else use pagination format
    url = "https://www.investing.com/news/most-popular-news"
    if page > 1:
        url += f"/{page}"
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            r = scraper.get(url, timeout=30)
            r.raise_for_status()
            soup = BeautifulSoup(r.text, "lxml")

            anchors = soup.select(
                'ul[data-test="news-list"] '
                'li article a[data-test="article-title-link"]'
            )
            return [a["href"] for a in anchors if a.has_attr("href")]
        except Exception as e:
            if attempt < MAX_RETRIES:
                backoff = 2 ** (attempt - 1) + random.random()
                time.sleep(backoff)
            else:
                print(f"Page {page} failed after {MAX_RETRIES}: {e}")
    return []

def robust_scrape(max_pages=10):
    first = fetch_page(1)
    PER_PAGE = len(first)
    if PER_PAGE == 0:
        raise RuntimeError("Failed to fetch the first page. Please check headers or cookies.")

    print(f"Fetched {PER_PAGE} links on page 1")

    results = {1: first}

    # Auto stop if only one page
    if max_pages == 1 or PER_PAGE == 0:
        print("Only one page detected or no pagination found.")
        return first

    pages = list(range(2, max_pages + 1))

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as pool:
        futures = {pool.submit(fetch_page, p): p for p in pages}
        for fut in as_completed(futures):
            p = futures[fut]
            results[p] = fut.result()

        for round in range(1, MAX_RETRIES + 1):
            bad = [p for p, links in results.items() if len(links) != PER_PAGE]
            if not bad:
                print(f"All pages OK after {round - 1} retries")
                break
            print(f"Retry round {round} for pages: {bad}")
            futures = {pool.submit(fetch_page, p): p for p in bad}
            for fut in as_completed(futures):
                p = futures[fut]
                results[p] = fut.result()
        else:
            print("Retry limit reached; some pages may still be incomplete.")

    total_fetched = sum(len(links) for links in results.values())
    expected = PER_PAGE * max_pages
    print(f"Total links fetched (including duplicates): {total_fetched} (expected {expected})")

    all_links = set(link for links in results.values() for link in links)
    print(f"Final: got {len(all_links)} unique URLs")
    return list(all_links)

if __name__ == "__main__":
    links = robust_scrape(max_pages=1)
# Out:
# Fetched 20 links on page 1
# Only one page detected or no pagination found.

# %%
links[1]
# Out:
# 'https://www.investing.com/news/stock-market-news/asia-stocks-dither-amid-trump-tariff-fears-mixed-china-inflation-4127419'

# %%
nest_asyncio.apply()

FETCH_WORKERS = min(32, os.cpu_count() * 4)  
PROCESS_WORKERS = os.cpu_count() or 4
MAX_FETCH_RETRIES = 3                      
RETRY_DELAY = 1                             
scraper = cloudscraper.create_scraper()

def is_placeholder(html: str) -> bool:
    lower = html.lower() if html else ""
    return (
        'temporarily down for maintenance' in lower
        or 'just a moment' in lower
        or "we're temporarily down" in lower
    )

def safe_find_datetime(url, html_content=None):
    try:
        # Strategy 1: Use htmldate library to extract date from URL
        dt = find_date(url)
        if dt:
            return dt, "00:00"  # Return with default time if date found
    except:
        pass
    
    if html_content:
        # Strategy 2: Look for American format with AM/PM
        m = re.search(r"(\d{1,2}/\d{1,2}/\d{4}),\s*(\d{1,2}:\d{2}\s*(?:AM|PM))", html_content)
        if m:
            ds, ts = m.groups()
            try:
                dt = datetime.strptime(f"{ds}, {ts}", "%m/%d/%Y, %I:%M %p")
                return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
            except:
                pass
        
        # Strategy 3: Look for numeric dates with 24-hour time format
        m = re.search(r"(\d{2}/\d{2}/\d{4}),\s*(\d{2}:\d{2})", html_content)
        if m:
            ds, ts = m.groups()
            # Try both European and American date formats
            for fmt in ("%d/%m/%Y, %H:%M", "%m/%d/%Y, %H:%M"):
                try:
                    dt = datetime.strptime(f"{ds}, {ts}", fmt)
                    return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
                except:
                    continue
    
    now = datetime.now()
    return now.strftime("%Y-%m-%d"), now.strftime("%H:%M")

def fetch_html(url, idx, total):
    for attempt in range(1, MAX_FETCH_RETRIES + 1):
        try:
            resp = scraper.get(url, timeout=30)
            html = resp.text
            if is_placeholder(html):
                raise RuntimeError('Placeholder')
                
            print(f"[Fetch][{idx}/{total}][ok]")
            return url, html
            
        except Exception:
            print(f"[Fetch][{idx}/{total}][retry {attempt}]")
            if attempt < MAX_FETCH_RETRIES:
                time.sleep(RETRY_DELAY)
                
    print(f"[Fetch error] {idx}/{total}: failed after {MAX_FETCH_RETRIES} retries")
    return url, None

def process_article(arg):
    url, html = arg
    if not html:
        return None
        
    art = Article(url)
    art.set_html(html)
    
    try:
        art.parse()
    except:
        return None
        
    text = art.text or ""
    title = (art.title or "").strip() or "No title"
    
    date, tm = safe_find_datetime(url, html)
    
    # Return combined data using dictionary unpacking
    return {'publish_date': date, 'publish_time': tm,
             'title': title, 'body_text': text, 'url': url}

async def scrape_all(urls):
    total = len(urls)
    loop = asyncio.get_event_loop()
    
    # Phase 1: Fetch HTML content from all URLs in parallel
    with ThreadPoolExecutor(max_workers=FETCH_WORKERS) as fetch_pool:
        # Create fetch tasks and run them through the thread pool
        fetch_tasks = [loop.run_in_executor(fetch_pool, fetch_html, u, i+1, total)
                       for i, u in enumerate(urls)]
        # Wait for all fetch tasks to complete
        fetched = await asyncio.gather(*fetch_tasks)

    # Phase 2: Process all fetched HTML content in parallel
    records = []
    with ThreadPoolExecutor(max_workers=PROCESS_WORKERS) as proc_pool:
        # Submit processing tasks only for URLs with successful fetches
        futures = {
            proc_pool.submit(process_article, fr): fr[0]
            for fr in fetched if fr[1]  # Skip URLs where HTML is None
        }
        
        # Process results as they complete
        for i, fut in enumerate(as_completed(futures), 1):
            res = fut.result()
            print(f"[Process][{i}/{total}] {futures[fut]}")
            if res:
                records.append(res)
                
    # Convert results to DataFrame
    return pd.DataFrame(records)

# ——— Main entry point function ———
def main(links):
    df = asyncio.get_event_loop().run_until_complete(scrape_all(links))
    return df

# Execute the main function if this script is run directly
if __name__ == '__main__':
    df = main(links)
# Out:
# [Fetch][7/20][ok]
# [Fetch][5/20][ok]
# [Fetch][18/20][ok]
# [Fetch][16/20][ok]
# [Fetch][4/20][ok]
# [Fetch][3/20][ok]
# [Fetch][15/20][ok]
# [Fetch][8/20][ok]
# [Fetch][11/20][ok]
# [Fetch][2/20][ok]
# [Fetch][9/20][ok]
# [Fetch][19/20][ok]
# [Fetch][13/20][ok]
# [Fetch][20/20][ok]
# [Fetch][10/20][ok]
# [Fetch][6/20][ok]
# [Fetch][12/20][ok]
# [Fetch][17/20][ok]
# [Fetch][14/20][ok]
# [Fetch][1/20][ok]
# [Process][1/20] https://www.investing.com/news/stock-market-news/tesla-bull-adam-jonas-warns-investors-may-need-to-brace-for-more-distractions-4125987
# [Process][2/20] https://www.investing.com/news/cryptocurrency-news/bitcoin-price-today-sticks-near-109k-as-traders-await-tariff-fallout-4127533
# [Process][3/20] https://www.investing.com/news/stock-market-news/trump-tariff-announcements-represent-mixed-news-for-markets-wolfe-research-says-4126073
# [Process][4/20] https://www.investing.com/news/stock-market-news/asia-stocks-dither-amid-trump-tariff-fears-mixed-china-inflation-4127419
# [Process][5/20] https://www.investing.com/news/stock-market-news/wall-street-analyst-warns-this-is-a-tipping-point-in-the-tesla-story-4126145
# [Process][6/20] https://www.investing.com/news/stock-market-news/these-could-be-the-5-biggest-pain-trades-in-the-second-half-hsbc-says-4126375
# [Process][7/20] https://www.investing.com/news/stock-market-news/us-stock-futures-fall-as-trump-tariffs-rattle-wall-street-4125571
# [Process][8/20] https://www.investing.com/news/stock-market-news/with-15-winners-in-july-these-aipicked-stocks-are-now-up-114-4125735
# [Process][9/20] https://www.investing.com/news/stock-market-news/its-dangerous-to-underestimate-corporate-america-bofa-ups-sp-500-target-4126179
# [Process][10/20] https://www.investing.com/news/economy-news/trump-sends-out-tariff-letters-extends-levy-deadline--whats-moving-markets-4125727
# [Process][11/20] https://www.investing.com/news/stock-market-news/could-a-summer-crisis-in-markets-happen-again-in-2025-deutsche-bank-weighs-in-4126178
# [Process][12/20] https://www.investing.com/news/stock-market-news/goldman-sachs-ups-sp-500-targets-on-supportive-policy-longterm-earnings-outlook-4125666
# [Process][13/20] https://www.investing.com/news/stock-market-news/apple-to-bid-for-formula-1-rights-in-us-amid-success-of-brad-pitt-film-ft-4127454
# [Process][14/20] https://www.investing.com/news/stock-market-news/citis-montagu-profittaking-risks-elevated-as-nasdaq-positioning-stretched-4125816
# [Process][15/20] https://www.investing.com/news/commodities-news/gold-prices-pressured-by-dollar-strength-copper-hits-record-high-on-trump-tariff-4127491
# [Process][16/20] https://www.investing.com/news/stock-market-news/super-micro-to-ramp-up-europe-manufacturing-amid-ai-demand-ceo-liang-tells-cnbc-4127426
# [Process][17/20] https://www.investing.com/news/stock-market-news/chinas-ambitious-ai-push-faces-supply-roadblock-in-nvidia-chip-haul--bloomberg-4127359
# [Process][18/20] https://www.investing.com/news/assorted/jeff-bezos-sells-nearly-3-million-amazon-shares-432SI-4127250
# [Process][19/20] https://www.investing.com/news/assorted/apple-names-sabih-khan-as-chief-operating-officer-432SI-4127275
# [Process][20/20] https://www.investing.com/news/cryptocurrency-news/bitcoin-price-today-dips-to-1082k-on-tariff-woes-trumps-shifting-deadline-4125658

# %%
df=df.sort_values(by=['publish_date', 'publish_time'], ascending=[False,False]).reset_index(drop=True)
df.head()
# Out:
#   publish_date publish_time  \
# 0   2025-07-09        02:30
# 1   2025-07-09        01:34
# 2   2025-07-09        00:42
# 3   2025-07-08        23:34
# 4   2025-07-08        22:47
#
#                                                title  \
# 0  Bitcoin price today: sticks near $109k as trad...
# 1  Gold prices pressured by dollar strength; Copp...
# 2  Apple to bid for Formula 1 rights in US amid s...
# 3  Super Micro to ramp up Europe manufacturing am...
# 4  Asia stocks dither amid Trump tariff fears, mi...
#
#                                            body_text  \
# 0  Investing.com-- gained slightly on Wednesday, ...
# 1  Investing.com-- Gold prices fell in Asian trad...
# 2  Investing.com-- Apple Inc (NASDAQ: ) is in tal...
# 3  Investing.com-- Super Micro Computer Inc (NASD...
# 4  Investing.com-- Most Asian stocks moved in a f...
#
#                                                  url
# 0  https://www.investing.com/news/cryptocurrency-...
# 1  https://www.investing.com/news/commodities-new...
# 2  https://www.investing.com/news/stock-market-ne...
# 3  https://www.investing.com/news/stock-market-ne...
# 4  https://www.investing.com/news/stock-market-ne...

# %%
pd.set_option('display.max_columns', None)

# %%
# Count empty body_text entries
empty_body_count = df[df['body_text'] == ''].shape[0]
print(f"Number of articles with empty body_text: {empty_body_count}")
# Out:
# Number of articles with empty body_text: 0

# %%
now = datetime.now()
date_time = now.strftime("%Y-%m-%d %H-%M-%S").strip().replace(' ', '_')
df.to_csv(f"data/trending_news/{date_time}.csv", index=False)
